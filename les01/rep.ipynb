# %% [markdown]
# # Отчёт по лабораторной работе №1
#
# Подготовка среды для анализа данных
#
# **Выполнил:** Блинов Кирилл Игоревич
#
# **Группа:** 12002408

# %% [markdown]
# ## Задание
#
# 1. Войти в GitHub и Google Colab.
# 2. Сделать форк репозитория курса.
# 3. Настроить интеграцию Colab и GitHub.
# 4. Оформить отчёт с помощью Markdown и сохранить его в папке `les01`.
# 5. Создать pull request и отправить ссылку в «Пегас».

# %% [markdown]
# ## Ход работы
#
# 1. Вошёл в свой аккаунт [GitHub](https://github.com/kir1lka) и Google Colab.
# 2. Сделал [форк репозитория](https://github.com/kir1lka/dap-2024).
# 3. Связал Colab с GitHub и сохранил отчёт в `les01/rep.ipynb`.
# 4. При оформлении использовал заголовки, нумерованный список, **жирный текст** и ссылки.
# 5. Создал [pull request](https://github.com/chebotarevsa/dap-2024/pull/121).

# %% [markdown]
# ## Вывод
#
# В ходе работы познакомился с Google Colab, сделал форк репозитория и настроил связь с GitHub. Научился оформлять текстовые ячейки с помощью Markdown и сохранять ноутбук в репозиторий.
